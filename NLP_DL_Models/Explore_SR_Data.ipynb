# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_colwidth', -1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.

# %%
sr_oakland_311_df = pd.read_csv("/Users/abhikbanerjee/Downloads/Service_requests_received_by_the_Oakland_Call_Center__OAK_311_.csv")

sr_kaggle_con_comp_df = pd.read_csv("/Users/abhikbanerjee/Downloads/Consumer_Complaints.csv")

# %%
sr_oakland_311_df.head()
# Out:
#    REQUESTID            DATETIMEINIT          SOURCE  \
# 0  462037     05/23/2013 09:16:01 AM  Phone or Email
# 1  461592     05/20/2013 07:11:56 PM  SeeClickFix
# 2  467764     06/28/2013 06:44:01 PM  SeeClickFix
# 3  468422     07/03/2013 12:40:43 PM  Phone or Email
# 4  461935     05/22/2013 01:27:35 PM  Phone or Email
#
#                                   DESCRIPTION REQCATEGORY  \
# 0  Illegal Dumping - debris, appliances, etc.  ILLDUMP
# 1  Illegal Dumping (report from SeeClickFix)   ILLDUMP
# 2  Illegal Dumping - debris, appliances, etc.  ILLDUMP
# 3  Illegal Dumping - debris, appliances, etc.  ILLDUMP
# 4  Illegal Dumping - debris, appliances, etc.  ILLDUMP
#
#                                   REQADDRESS  STATUS REFERREDTO  \
# 0  (37.76976038862182, -122.21307311813602)   CLOSED  NaN
# 1  (37.810393973488175, -122.30226500554511)  CLOSED  NaN
# 2  (37.81916313695426, -122.27423685524602)   CLOSED  NaN
# 3  (37.76882353027444, -122.207418481692)     CLOSED  NaN
# ...

# %%
sr_oakland_311_df["DESCRIPTION"].unique()
# Out:
# array(['Illegal Dumping - debris, appliances, etc.',
#        'Illegal Dumping (report from SeeClickFix)',
#        'Other (report from SeeClickFix', 'Sidewalk - Damage',
#        'Hazardous Materials', 'Miscellaneous',
#        'Construction and Demolition Recycling', 'Litter in Parks',
#        'Graffiti on Private Property', 'City Bldg - Structural Issue',
#        'Graffiti in a Park', 'Graffiti (report from SeeClickFix)',
#        'Electrical - Street Light (report from SeeClickFix',
#        'TE - Traffic Safety (non-emergency)',
#        'TE - Traffic Control Plan Review', 'Tree - Pruning',
#        'Traffic - Repair Pavement Striping',
#        'Illegal Dumping � mattress/boxspring',
#        'Traffic - Signals - Timing Change Request NON EMER',
#        'Streets - Potholes/Depression', 'Recycling - Oil Kit Request',
#        'Sewers - Blockage', 'Parks and Street Medians - Irrigation',
#        'Graffiti on Traffic Sign(s)', 'Illegal Dumping � green waste',
# ...

# %%
sr_oakland_311_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691303 entries, 0 to 691302
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   REQUESTID        691303 non-null  int64
#  1   DATETIMEINIT     691303 non-null  object
#  2   SOURCE           691303 non-null  object
#  3   DESCRIPTION      691303 non-null  object
#  4   REQCATEGORY      691226 non-null  object
#  5   REQADDRESS       678470 non-null  object
#  6   STATUS           691303 non-null  object
#  7   REFERREDTO       61304 non-null   object
#  8   DATETIMECLOSED   491333 non-null  object
#  9   SRX              678470 non-null  float64
#  10  SRY              678470 non-null  float64
#  11  COUNCILDISTRICT  654141 non-null  object
#  12  BEAT             655896 non-null  object
#  13  PROBADDRESS      690839 non-null  object
#  14  City             691303 non-null  object
#  15  State            691303 non-null  object
# ...

# %%
sr_kaggle_con_comp_df.head()
# Out:
#   Date received           Product     Sub-product  \
# 0  3/12/2014     Mortgage          Other mortgage
# 1  10/1/2016     Credit reporting  NaN
# 2  10/17/2016    Consumer Loan     Vehicle loan
# 3  6/8/2014      Credit card       NaN
# 4  9/13/2014     Debt collection   Credit card
#
#                                       Issue                   Sub-issue  \
# 0  Loan modification,collection,foreclosure  NaN
# 1  Incorrect information on credit report    Account status
# 2  Managing the loan or lease                NaN
# 3  Bankruptcy                                NaN
# 4  Communication tactics                     Frequent or repeated calls
#
# ...

# %%
sr_kaggle_con_comp_df[["Product", "Issue", "Consumer complaint narrative", "Company public response"]].head(n=50)
# Out:
#                     Product                                     Issue  \
# 0   Mortgage                 Loan modification,collection,foreclosure
# 1   Credit reporting         Incorrect information on credit report
# 2   Consumer Loan            Managing the loan or lease
# 3   Credit card              Bankruptcy
# 4   Debt collection          Communication tactics
# 5   Mortgage                 Loan servicing, payments, escrow account
# 6   Debt collection          Improper contact or sharing of info
# 7   Credit reporting         Credit reporting company's investigation
# 8   Mortgage                 Loan modification,collection,foreclosure
# 9   Mortgage                 Loan modification,collection,foreclosure
# 10  Mortgage                 Loan modification,collection,foreclosure
# 11  Student loan             Repaying your loan
# 12  Debt collection          Disclosure verification of debt
# 13  Credit reporting         Incorrect information on credit report
# ...

# %%
sr_kaggle_con_comp_df["Consumer complaint narrative"].nunique()
# Out:
# 195317

# %%
sr_kaggle_con_comp_df_filtered = sr_kaggle_con_comp_df[sr_kaggle_con_comp_df["Consumer complaint narrative"].notnull()]

# %%
sr_kaggle_con_comp_df_filtered["Consumer complaint narrative"].head(n=30)
# Out:
# 1      I have outdated information on my credit report that I have previously disputed that has yet to be removed this information is more then seven years old and does not meet credit reporting requirements
# ...
